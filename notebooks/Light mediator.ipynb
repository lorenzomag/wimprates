# %%
import logging
logging.basicConfig(level=logging.INFO)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import wimprates as wr
# Out:
# WARNING:wimprates:Default WIMP parameters are changed in accordance with https://arxiv.org/abs/2105.00599 (github.com/JelleAalbers/wimprates/pull/14)
# /home/loren/projects/wimprates/wimprates/utils.py:12: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# ------------------------------------------
# Migdal ionisation probabilities
# P. Cox, M. Dolan, C. McCabe, H. Quiney (2022)
# arXiv:2208.12222
# ------------------------------------------

# %%
es = np.linspace(0.01, 30, 100)
plt.plot(es, wr.rate_wimp_std(es, mw=100, sigma_nucleon=1e-46),
         label=r'$m_\phi = \infty$, $\sigma = 10^{-46} \mathrm{cm}^2$')
plt.plot(es, wr.rate_wimp_std(es, mw=100, m_med=0.01, sigma_nucleon=6.5e-44),
         label=r'$m_\phi = 10 \mathrm{MeV}/c^2$, $\sigma = 6.5 \times 10^{-44} \mathrm{cm}^2$',
         color='g')
plt.plot(es, wr.rate_wimp_std(es, mw=100, m_med=0.001, sigma_nucleon=6e-40),
         label=r'$m_\phi = 1 \mathrm{MeV}/c^2$, $\sigma = 6 \times 10^{-40} \mathrm{cm}^2$',
         color='r')

plt.legend(loc='upper right')
plt.xlabel('Recoil energy (keV)')
plt.ylabel('Events / (kg keV day)')
plt.yscale('log')
plt.ylim(1e-1, 1e2)
plt.title(r'$m_\chi = 200 \mathrm{GeV}/c^2$')
plt.savefig('light_mediator_effect.png')

# %% [markdown]
# TODO: the light mediator Migdal spectra are incorrect!

# %%
es = np.linspace(0.01, 2, 100)
plt.plot(es, wr.rate_wimp_std(es, mw=0.5, sigma_nucleon=1e-39,
                              detection_mechanism='migdal'),
         label=r'$m_\phi = \infty$, $\sigma = 10^{-39} \mathrm{cm}^2$')
plt.plot(es, wr.rate_wimp_std(es, mw=0.5, m_med=0.001, sigma_nucleon=1e-39,
                              detection_mechanism='migdal'),
         color='red',
         label=r'$m_\phi = 1 \mathrm{MeV}/c^2$, $\sigma = 10^{-39} \mathrm{cm}^2$')

plt.legend(loc='upper right')
plt.xlabel('Recoil energy (keV)')
plt.ylabel('Events / (kg keV day)')
plt.yscale('log')
plt.title(r"$m_\chi = 0.5 \mathrm{GeV}/c^2$")
plt.savefig('light_mediator_migdal.png')
